# %% [markdown]
# # Cómo ejecuta Python los programas

# %%
print('hello world')
print(2 ** 100)

# %% [markdown]
# ### C:\code> python script0.py
# ### hello world
# ### 1267650600228229401496703205376

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Implicaciones de rendimiento

# %% [markdown]
# ## Implicaciones para el desarrollo

# %% [markdown]
# # Cómo se ejecutan los programas

# %% [markdown]
# ## 1) The Interactive Prompt
# ## 2) IPython
# ## 3) IDE
# ## 4) Jupyter notebooks

# %% [markdown]
# # Module Imports and Reloads

# %%
import os

# %%
os.cpu_count()

# %% [markdown]
# # Modules and namespaces

# %% [markdown]
# # The IDLE User Interface

# %% [markdown]
# # Types and Operations

# %% [markdown]
# # Python Object Types

# %% [markdown]
# ## La jerarquía conceptual de Python

# %% [markdown]
# 1. Programs are composed of modules.
#
# 2. Modules contain statements.
#
# 3. Statements contain expressions.
#
# 4. Expressions create and process objects.

# %% [markdown]
# # Tipos de datos básicos de Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  Numeros

# %%
123 + 222

# %%
1.5 * 4

# %%
2 ** 100

# %%
len(str(2 ** 1000000))

# %%
3.1415 * 2

# %%
print(3.1415 * 2)

# %%
import math

# %% [markdown]
# #### math es una biblioteca integrada que se entrega con todas las versiones de Python. Se utiliza para realizar operaciones matemáticas en datos escalares, como los cálculos trigonométricos.

# %%
math.pi

# %%
math.sqrt(85)

# %% [markdown]
# #### El módulo "math" contiene herramientas numéricas más avanzadas como funciones, mientras que el módulo aleatorio realiza la generación de números aleatorios y selecciones aleatorias

# %%
import random

# %%
random.random()

# %%
random.choice([1, 2, 3, 4])

# %%
import statistics

# %% [markdown]
# ## Strings (cadenas de caracteres)

# %% [markdown]
# ### Operaciones de secuencia

# %%
S = 'Spam'           #

# %%
len(S)

# %%
S[0]

# %%
S[1]

# %%
S[-1]

# %%
S[-2]

# %%
S[len(S)-1]

# %%
S

# %%
S[1:3]

# %%
S[1:]

# %%
S[0:3]

# %%
S[:3]

# %%
S[:]

# %%
S + 'xyz'

# %%
S * 8

# %%
help(S.replace)

# %%
S.replace?

# %% [markdown]
# ### Immutabiliidad

# %%
S[0] = 'z'

# %%
S = 'z' + S[1:]

# %%
S

# %%
S = 'shrubbery'

# %%
L = list(S)

# %%
L

# %%
L[1] = 'c'

# %%
''.join(L)

# %%
B = bytearray(b'spam')

# %%
B.extend(b'eggs')

# %%
B

# %%
B.decode()

# %% [markdown]
# ### Type-Specific Methods

# %%
S = 'Spam'

# %%
S.find('pa')

# %%
S.replace('pa', 'XYZ')

# %%
S

# %%
line = 'aaa,bbb,ccccc,dd'

# %%
line.split(',')

# %%
dir(S)

# %% [markdown]
# # Lists (listas)

# %%
L = [123, 'spam', 1.23]

# %%
len(L)

# %%
L[0]

# %%
L[:-1]

# %%
L + [4, 5, 6]

# %%
L * 2

# %%
LL.append('NI')

# %%
L

# %%
L.pop(2)

# %%
L

# %% [markdown]
# ## Bounds Checking

# %%
L

# %%
L[99]

# %%
L[99] = 1

# %% [markdown]
# ### Nesting

# %%
M = [[1, 2, 3],               # A 3 × 3 matrix, as nested lists
         [4, 5, 6],               # Code can span lines if bracketed
         [7, 8, 9]]

# %%
M

# %%
M[1]                          # Get row 2

# %%
M[1][2]

# %%
[row[1] for row in M]             # Collect the items in column 2

# %%
[row[1] + 1 for row in M]                 # Add 1 to each item in column 2

# %%
[row[1] for row in M if row[1] % 2 == 0]  # Filter out odd items

# %%
diag = [M[i][i] for i in [0, 1, 2]]      # Collect a diagonal from matrix

# %%
diag

# %%
doubles = [c * 2 for c in 'spam']        # Repeat characters in a string

# %%
doubles

# %%
list(range(4))                           # 0..3 (list() required in 3.X)

# %%
list(range(-6, 7, 2))                    # −6 to +6 by 2 (need list() in 3.X)

# %%
[[x ** 2, x ** 3] for x in range(4)]     # Multiple values, "if" filters

# %%
[[x, x / 2, x * 2] for x in range(-6, 7, 2) if x > 0]

# %%
G = (sum(row) for row in M)              # Create a generator of row sums
