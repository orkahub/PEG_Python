# %%
import rips
import pandas as pd
# Out:
# c:\users\prime\appdata\local\programs\python\python37\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\prime\appdata\local\programs\python\python37\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# c:\users\prime\appdata\local\programs\python\python37\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
input_matrix_file = "DOE_EX3_with_index.csv"
im_df = pd.read_csv(input_matrix_file)
im_df
# Out:
#     index heterogeneity_index  variogram_angle  max_lateral_connectivity  \
# 0       1                   1                2                         1
# 1       2                   3                2                         1
# 2       3                   1                3                         1
# 3       4                   3                3                         1
# 4       5                   1                2                         3
# ..    ...                 ...              ...                       ...
# 68     69                zero                0                         0
# 69     70                zero                0                         0
# 70     71                zero                0                         0
# 71     72                zero                0                         0
# 72     73                   2                2                         2
#
#    mob_ratio  mean_permeability  kvhk
# 0        low                  1     1
# ...

# %%
im_df.describe().T
# Out:
#                           count       mean        std  min   25%   50%   75%  \
# index                      73.0  37.000000  21.217131  1.0  19.0  37.0  55.0
# variogram_angle            73.0   2.219178   0.916615  0.0   2.0   2.0   3.0
# max_lateral_connectivity   73.0   1.780822   1.133414  0.0   1.0   1.0   3.0
# mean_permeability          73.0   2.000000   1.000000  1.0   1.0   2.0   3.0
# kvhk                       73.0   2.000000   1.000000  1.0   1.0   2.0   3.0
#
#                            max
# index                     73.0
# variogram_angle            3.0
# max_lateral_connectivity   3.0
# mean_permeability          3.0
# kvhk                       3.0

# %%
indeces = [0,1]
cases_path = r'./models'
prefix = 'CASE_REV2_EX3_'
extension = '.EGRID'
cases_names = []
for index in indeces:
    cases_names.append(cases_path+'/'+prefix+str(index)+extension)
cases_names
# Out:
# ['./models/CASE_REV2_EX3_0.EGRID', './models/CASE_REV2_EX3_1.EGRID']

# %%
path = r'M:\apps\ResInsight-2020.04.1_oct-4.0.0_win64\ResInsight-2020.04.1_oct-4.0.0_win64\ResInsight.exe'
ri = rips.Instance.launch(path)
# Out:
# Trying port 50051
# Trying port 50052
# Trying port 50053
# Port 50053
# Trying to launch M:\apps\ResInsight-2020.04.1_oct-4.0.0_win64\ResInsight-2020.04.1_oct-4.0.0_win64\ResInsight.exe

# %%
for case in cases_names:
    ri.project.load_case(case)

# %%
ri_cases = ri.project.cases()
for ri_case in ri_cases:
    view = ri_case.views()[0]
    view.apply_cell_result('STATIC_NATIVE', 'PERMX')
    view.set_visible(True)
